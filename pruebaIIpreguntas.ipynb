# %%
#mensajes de bienvenida 
nombre_jugador = input("Indícame tu nombre: ")
print(f"Hola {nombre_jugador.upper()}, ¡Veamos cuanto sabes!")
bienvenida2 = print('Elige categoría y dificultad')
bienvenida3 = print('Lucha por tu self.vida')
# Out:
# Hola , ¡Veamos cuanto sabes!
# Elige categoría y dificultad
# Lucha por tu self.vida

# %%
#importamos random para que elija las opciones del diccionario 
import random

# %%
#creamos lista con diccionarios de preguntas para poder iterar con bucle for 
preguntas_total = {
    'Geografia': {
        'Baja': {
            '¿Es portugal un país Europeo?': 'Si', 
            '¿Es el río Nilo el más largo del mundo?': 'No', 
            '¿Es Dublín la capital de Irlanda?': 'Si',
            '¿Es el Océano Pacífico el más grande de la Tierra?': 'Si',
            '¿Se encuentra el desierto del Sahara en África?': 'Si',
            '¿Es Madrid una ciudad con costa?': 'No'
        },
        'Alta': {
            '¿Es Francia el país con más husos horarios en su territorio?': 'Si', 
            '¿Es La Paz la capital más alta del mundo?': 'Si', 
            '¿El Canal de la Mancha separa Marruecos y España?': 'No',
            '¿Es el Everest la montaña más alejada del centro de la Tierra?': 'No', 
            '¿Es el Vaticano el país más pequeño del mundo?': 'Si',
            '¿Pertenece Groenlandia a Canadá?': 'No'
        }
    },
    'Historia': {
        'Baja': {
            '¿Fue Napoleón derrotado en la batalla de Waterloo?': 'Si', 
            '¿El Titanic se hundió en 1914?': 'No', 
            '¿Los Romanos hablaban latín?': 'Si',
            '¿Fue Cristóbal Colón quien llegó a América en 1492?': 'Si',
            '¿Construyeron los Egipcios las pirámides de Giza?': 'Si',
            '¿Inventó Alexander Graham Bell el teléfono móvil?': 'No'
        },
        'Alta': {
            '¿El Muro de Berlín cayó en 1979?': 'No', 
            '¿Fue Abraham Lincoln el primer presidente de EEUU?': 'No', 
            '¿La Ruta de la Seda era la ruta comercial que conectaba China con Europa?': 'Si',
            '¿Duró la "Guerra de los Cien Años" exactamente 100 años?': 'No',
            '¿Fue Cleopatra la última faraona de Egipto?': 'Si',
            '¿Se firmó la Constitución Española en 1978?': 'Si'
        }
    }
}

# %%
#importamos random para que elija las opciones del diccionario 
import random 
#mensajes de bienvenida 
nombre_jugador = input("Indícame tu nombre: ")
print(f"Hola {nombre_jugador.upper()}, ¡Veamos cuanto sabes!")
bienvenida2 = print('Elige categoría y dificultad')
bienvenida3 = print('Lucha por tu self.vida')
#creamos lista con diccionarios de preguntas para poder iterar con bucle for 
preguntas_total = {
    'Geografia': {
        'Baja': {
            '¿Es portugal un país Europeo?': 'Si', 
            '¿Es el río Nilo el más largo del mundo?': 'No', 
            '¿Es Dublín la capital de Irlanda?': 'Si',
            '¿Es el Océano Pacífico el más grande de la Tierra?': 'Si',
            '¿Se encuentra el desierto del Sahara en África?': 'Si',
            '¿Es Madrid una ciudad con costa?': 'No'
        },
        'Alta': {
            '¿Es Francia el país con más husos horarios en su territorio?': 'Si', 
            '¿Es La Paz la capital más alta del mundo?': 'Si', 
            '¿El Canal de la Mancha separa Marruecos y España?': 'No',
            '¿Es el Everest la montaña más alejada del centro de la Tierra?': 'No', 
            '¿Es el Vaticano el país más pequeño del mundo?': 'Si',
            '¿Pertenece Groenlandia a Canadá?': 'No'
        }
    },
    'Historia': {
        'Baja': {
            '¿Fue Napoleón derrotado en la batalla de Waterloo?': 'Si', 
            '¿El Titanic se hundió en 1914?': 'No', 
            '¿Los Romanos hablaban latín?': 'Si',
            '¿Fue Cristóbal Colón quien llegó a América en 1492?': 'Si',
            '¿Construyeron los Egipcios las pirámides de Giza?': 'Si',
            '¿Inventó Alexander Graham Bell el teléfono móvil?': 'No'
        },
        'Alta': {
            '¿El Muro de Berlín cayó en 1979?': 'No', 
            '¿Fue Abraham Lincoln el primer presidente de EEUU?': 'No', 
            '¿La Ruta de la Seda era la ruta comercial que conectaba China con Europa?': 'Si',
            '¿Duró la "Guerra de los Cien Años" exactamente 100 años?': 'No',
            '¿Fue Cleopatra la última faraona de Egipto?': 'Si',
            '¿Se firmó la Constitución Española en 1978?': 'Si'
        }
    }
}
recompensa1 = '🔓' #para cuando la respuesta sea correcta 
recompensa2 = '🔒' #para cuando sea incorrecta 
recompensa3 = '⭐' #total de puntos 
vida = '💟'
mal = '❌'
bien = '✅'
def preguntar(categoria,nivel):
    global inicio_recompensa, inicio_vidas, puntos_suma, preguntas_realizadas
    preguntas_diccionario = preguntas_total[categoria][nivel]
    pregunta = random.choice(list(preguntas_diccionario.keys()))
    solucion = preguntas_diccionario[pregunta]

    print(f"La pregunta es: {pregunta}")
    respuesta = input("¿Cuál es tu respuesta?").capitalize()

    if respuesta == solucion.capitalize():
        puntos_suma = 2 if nivel == 'Alto' else 1
        inicio_recompensa += puntos_suma
        print(f"¡Genial! {recompensa1}. Sumas {puntos_suma} puntos. Total {inicio_recompensa}")
    elif respuesta != solucion.capitalize():
        inicio_vidas -= 1
        print(f"¡Oh no! No has desbloqueado la recompensa {recompensa2}. Te quedan {inicio_vidas} {vida} vidas")
    else:
        pass
    preguntas_realizadas += 1

while True:

    max_preguntas = 5
    preguntas_realizadas = 0
    total_vidas = 0
    inicio_recompensa = 0 
    total_recompensa = 0
    inicio_vidas = 3
    puntos_suma = 0
    contador_rondas = 0 

#creamos bucle para que el juego no se ejecute solo una vez
    while inicio_vidas > total_vidas and preguntas_realizadas < max_preguntas: 
    #contador de rondas     
        for ronda in range(1, 6):
            contador_rondas += 1
            print(f"------ RONDA {contador_rondas} ------") 
        #creamos la pregunta para que el usuario elija
            opciones = ['Geografia', 'Historia']
            opciones2 = ['Baja', 'Alta']
            preguntac = input('Categoría: Geografia o Historia').capitalize()
            preguntad = input('Dificultad: Alta o Baja?').capitalize()
        #acotamos las opciones que puede dar el usuario 
            if preguntac in opciones and preguntad in opciones2:
                print('Debes contestar Si o No, ¿ready?')
                preguntar(preguntac, preguntad)
            elif preguntac not in opciones or preguntad not in opciones2:
                print("Debes elegir categoría y dificultad")
            else:
                pass  

    print('-------------------------------------')
    if inicio_vidas == total_vidas:
        print('¡ESTUDIA Y VUELVE!')
    elif inicio_recompensa == total_recompensa: 
        print(nombre_jugador,'¡HAS GANADO!')
    else:
        pass 

    while True:
        volver_a_jugar = input('Nueva partida, nuevas preguntas. ¿Te atreves?').lower().strip()
        if volver_a_jugar in ('si', 'no'):
           break  
        
        else:
            print('Elige si o no')

    if volver_a_jugar == 'no':
        print('GRACIAS POR JUGAR')
        break
    else:
        print('----------------------------')
        print('¡NUEVA PARTIDA!')
# Out:
# Hola ROCIO, ¡Veamos cuanto sabes!
# Elige categoría y dificultad
# Lucha por tu self.vida
# ------ RONDA 1 ------
# Debes contestar Si o No, ¿ready?
# La pregunta es: ¿Es el Vaticano el país más pequeño del mundo?
# ¡Oh no! No has desbloqueado la recompensa 🔒. Te quedan 2 💟 vidas
# ------ RONDA 2 ------
# Debes contestar Si o No, ¿ready?
# La pregunta es: ¿Duró la "Guerra de los Cien Años" exactamente 100 años?
# ¡Oh no! No has desbloqueado la recompensa 🔒. Te quedan 1 💟 vidas
# ------ RONDA 3 ------
# Debes contestar Si o No, ¿ready?
# La pregunta es: ¿Pertenece Groenlandia a Canadá?
# ¡Oh no! No has desbloqueado la recompensa 🔒. Te quedan 0 💟 vidas
# ------ RONDA 4 ------
# Debes elegir categoría y dificultad
# ------ RONDA 5 ------
# Debes contestar Si o No, ¿ready?
# La pregunta es: ¿El Canal de la Mancha separa Marruecos y España?
# ¡Genial! 🔓. Sumas 1 puntos. Total 1
# -------------------------------------
# ¡ESTUDIA Y VUELVE!
# GRACIAS POR JUGAR
