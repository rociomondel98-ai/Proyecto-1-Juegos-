# %%
#BIENVENIDA Y FORMATO DE LAS RESPUESTAS

#Recursos:
opciones=["Piedra", "Papel", "Tijera"]#creo la lista con las posibles opciones para tenerlas a mano
puntos_jugador=0
puntos_jugador_pc=0
intentos_totales=3

#input para nombre:
nombre = input("¿Cómo te llamas?").strip().title()#le pregunto el nombre y uso función stip por si mete algún espacio en blanco.Uso también .Title()porque el formato que quiero que devuelva es Title,es decir solamente la primera en mayúsculas.Porque así va estar en las opciones.
print(f"Hola {nombre} Bienvenida al juego Piedra, Papel, Tijera 🎮")

#input para respuesta:
respuesta=input(f"Elige una de las siguientes opciones {opciones}").strip().title()
if respuesta in opciones:#si la respuesta está en las opciones,imprime la respuesta independientemente de que esté en may,min o de que haya espacios
    print(respuesta)
else:
    print("El valor introducido no está en opciones")

    print("Introduce Piedra ✊🏻, Papel ✋🏻o Tijera ✌🏻")
# Out:
# Hola Jesica Bienvenida al juego Piedra, Papel, Tijera 🎮
# Piedra

# %%
#BIENVENIDA Y FORMATO DE LAS RESPUESTAS

#Recursos:
import random
opciones=["Piedra", "Papel", "Tijera"]#creo la lista con las posibles opciones para tenerlas a mano
#condiciones
#IF si el jugador_humano es==al pc:empate"ha habido un empate"
#IF si el jugador_humano==piedra y el pc tijera:"jugador_humano ha ganado"
#IF si el jugador_humano==tijera y el pc papel :"jugador_humano ha ganado"
#IF si el jugador_humano==papel y el pc piedra:"jugador_humano ha ganado"
#SINO"else":
    #pc ha ganado


#input para nombre:
nombre = input("¿Cómo te llamas?").strip().title()#le pregunto el nombre y uso función stip por si mete algún espacio en blanco.Uso también .Title()porque el formato que quiero que devuelva es Title,es decir solamente la primera en mayúsculas.Porque así va estar en las opciones.
print(f"Hola {nombre} bienvenida al juego Piedra, Papel, Tijera 🎮")
print(f"Introduce una de las siguientes opciones ´{opciones} ✊🏻✋🏻✌🏻")

#definir jugadores:
jugador_humano=input(f"Elige una de las siguientes opciones {opciones}").strip().title()
if jugador_humano in opciones:#si la respuesta está en las opciones,imprime la respuesta independientemente de que esté en may,min o de que haya espacios
    print(f"👩🏻{jugador_humano}")
else:
    print("El valor introducido no está en opciones")

    print("Introduce Piedra ✊🏻, Papel ✋🏻o Tijera ✌🏻")

jugador_pc=random.choice(opciones)
print(f"🤖{jugador_pc}" )

#definir condiciones:

if jugador_humano==jugador_pc:
    print("Ha habido un empate")
elif jugador_humano=="Piedra" and jugador_pc=="Tijera":
    print("humano ha ganado")
elif jugador_humano=="Papel" and jugador_pc=="Piedra":
    print("humano ha ganado")
elif jugador_humano=="Tijera" and jugador_pc=="Papel":
    print("humano ha ganado")
else:
    print("jugador_pc ha ganado")


#ojo:Tengo que ponerle que si el usuario se equivoca al introducir la respuesta,no gane el pc,que le de 3 intentos de cada vez
#También debo de poner que pueda jugar muchas veces, no solo 1
#Tampoco quiero que me pregunte el nombre antes de que se acaben los intentos
#me faltará un while
# Out:
# Hola Jesica bienvenida al juego Piedra, Papel, Tijera 🎮
# Introduce una de las siguientes opciones ´['Piedra', 'Papel', 'Tijera'] ✊🏻✋🏻✌🏻
# El valor introducido no está en opciones
# Introduce Piedra ✊🏻, Papel ✋🏻o Tijera ✌🏻
# 🤖Piedra
# jugador_pc ha ganado

# %%
#BIENVENIDA Y FORMATO DE LAS RESPUESTAS

#Recursos:

#creo diccionario con facil y diccionario con dificl y dentro le pongo los valores
preguntas_Diccionario={
    "facil": {
        "España está en Europa": True,
        "El Amazonas es el río más largo del mundo": False,
        "África es el continente más grande": False
    },
    "dificil": {
        "Australia es a la vez un país y un continente": True,
        "El desierto del Sahara está en Asia": False,
        "Canadá tiene más lagos que el resto del mundo combinado": True
    }
}

#input para nombre:
nombre = input("¿Cómo te llamas?").strip().title()#le pregunto el nombre y uso función strip por si mete algún espacio en blanco.Uso también .Title()porque el formato que quiero que devuelva es Title,es decir solamente la primera en mayúsculas.Porque así va estar en las opciones.
print(f"Hola {nombre} Bienvenida/a al juego Preguntas y respuestas🎮")


#input para respuesta:
nivel = input("Elige dificultad (facil / dificil): ").strip().lower()

for pregunta in preguntas_Diccionario[nivel]:#para la pregunta en el diccionario nivel 0 fácil,nivel1 difícil
    print(pregunta)
# Out:
# Hola Jesica Bienvenida/a al juego Preguntas y respuestas🎮
# España está en Europa
# Incorrecto ❌
# El Amazonas es el río más largo del mundo
# Correcto ✅
# África es el continente más grande
# Correcto ✅
