# %%
#definir dos jugadores - el usuario y la maquina 
 #¿como hacer maquina?
#crear un input que de la bienvenida
#crear un input que te pregunte cual eliges
#crear funcion random para que la maquina elija uno - después del usuario para que no pueda hacer trampas 
#delimitar opciones con condicionales 
#crear un bucle - la partida es a 3 y van ganando puntos

# %%
#importamos random para usarlo en la computadora
import random

# %%
#definimos los dos jugadores
jugador_1 = 'usuario'
jugador_2 = 'PC'

# %%
#creamos mensaje de bienvenida
jugadora = input('¿Cómo te llamas?')
bienvenida = print('¡Bienvenida', jugadora, 'al juego de Piedra, Papel o Tijera!')
bienvenida2 = print('Hoy, por ser tu primera vez, vamos a jugar al mejor de tres. Te enfrentarás a la computadora. ¿Estás preparada?')
#creamos las preguntas para los dos jugadores
opciones = ['Piedra', 'Papel', 'Tijera']
jugador_1 = input('Elige una de las opciones: Piedra, Papel o Tijera').capitalize() #he usado capitalize para que si el usuario lo escribe en minúscula no de error el código 
#acotamos las respuestas que puede dar el jugador1
if jugador_1 in opciones:
    print(jugador_1)
else:
    if jugador_1 in opciones:
        print(jugador_1)
    elif jugador_1 != opciones:
        print('¡Tienes que elegir entre estas tres opciones! Piedra, Papel o Tijera')
    else:    
        pass 
#creamos las opciones para delimitar cada respuesta y lo que significa en la partida 
if jugador_1 in opciones:
    jugador_2 = (random.choice(['Piedra', 'Papel', 'Tijera']))
    print(jugador_2)
    if jugador_1 == jugador_2:
        print("¡Tenemos un empate!")
    elif jugador_1 != jugador_2:
        if jugador_1 == 'Piedra' and jugador_2 == 'Papel':
            print('¡Gana', jugadora,'!')
        elif jugador_1 == 'Piedra' and jugador_2 == 'Tijera':
            print('¡Gana', jugadora,'!')
        elif jugador_1 == 'Tijera' and jugador_2 == 'Papel':
            print('¡Gana', jugadora,'!')
        elif jugador_2 == 'Piedra' and jugador_1 == 'Papel':
            print('¡Gana nuestra computadora! Ponte las pilas', jugadora,'!')
        elif jugador_2 == 'Piedra' and jugador_1 == 'Tijera':
            print('¡Gana nuestra computadora! Cuidado con la revolución de las máquinas', jugadora,'!')
        elif jugador_2 == 'Tijera' and jugador_1 == 'Papel':
            print('¡Gana nuestra computadora! What´s happening', jugadora,'?!')
        else:
            pass
# Out:
# ¡Bienvenida Rocio al juego de Piedra, Papel o Tijera!
# Hoy, por ser tu primera vez, vamos a jugar al mejor de tres. Te enfrentarás a la computadora. ¿Estás preparada?
# Piedra
# Tijera
# ¡Gana Rocio !

# %%
#vidas
intentos_final = 0
vidas = 3
vida_1 = '🌕'
vida_2 = '🌗'
vida_3 = '🌚'
#creamos mensaje de bienvenida
jugadora = input('¿Cómo te llamas?')
bienvenida = print('¡Bienvenida', jugadora, 'al juego de Piedra, Papel o Tijera!')
bienvenida2 = print('Hoy, por ser tu primera vez, vamos a jugar al mejor de tres. Te enfrentarás a la computadora. ¿Estás preparada?')
#creamos bucle para que el juego no se ejecute solo una vez
print('Actualmente tienes',vidas,'vidas. Cada vez que falles se te restará una. Si te quedas sin vidas pierdes la partida')
#creamos las preguntas para los dos jugadores
opciones = ['Piedra', 'Papel', 'Tijera']
jugador_1 = input('Elige una de las opciones: Piedra, Papel o Tijera').capitalize() #he usado capitalize para que si el usuario lo escribe en minúscula no de error el código 
#acotamos las respuestas que puede dar el jugador1
if jugador_1 in opciones:
    print(jugador_1)
else:
    if jugador_1 in opciones:
        print(jugador_1)
    elif jugador_1 != opciones:
        print('¡Tienes que elegir entre estas tres opciones! Piedra, Papel o Tijera')
    else:    
        pass 
#creamos las opciones para delimitar cada respuesta y lo que significa en la partida 
if jugador_1 in opciones:
    jugador_2 = (random.choice(['Piedra', 'Papel', 'Tijera']))
    print(jugador_2)
    if jugador_1 == jugador_2:
        print("¡Tenemos un empate!")
        print("¡Tus vidas siguen intactas, por los pelos!")
    elif jugador_1 != jugador_2:
        if jugador_1 == 'Piedra' and jugador_2 == 'Papel':
            print('¡Gana',jugadora,'!')
        elif jugador_1 == 'Piedra' and jugador_2 == 'Tijera':
            print('¡Gana',jugadora,'!')
        elif jugador_1 == 'Tijera' and jugador_2 == 'Papel':
            print('¡Gana',jugadora,'!')
        elif jugador_2 == 'Piedra' and jugador_1 == 'Papel':
            vidas -= 1 
            print('¡Gana nuestra computadora! Ponte las pilas,',jugadora,'!')
            print('Oh no,',jugadora,'has perdido una vida!',vida_1,'. Te quedan un total de:',vidas)
        elif jugador_2 == 'Piedra' and jugador_1 == 'Tijera':
            vidas -= 1  
            print('¡Gana nuestra computadora! Cuidado con la revolución de las máquinas',jugadora,'!')
            print('Oh no,',jugadora,'has perdido una vida!',vida_2,'. Te quedan un total de:',vidas)
        elif jugador_2 == 'Tijera' and jugador_1 == 'Papel':
            vidas -= 1  
            print('¡Gana nuestra computadora! What´s happening',jugadora,'?!')
            print('Oh no,',jugadora,'has perdido una vida!',vida_2,'. Te quedan un total de:',vidas)
        else:
            pass 
if vidas == intentos_final:
    print('Se acabó el juego',jugadora,'¡Inténtalo otra vez cuando te veas con fuerzas!')
# Out:
# ¡Bienvenida Nani al juego de Piedra, Papel o Tijera!
# Hoy, por ser tu primera vez, vamos a jugar al mejor de tres. Te enfrentarás a la computadora. ¿Estás preparada?
# Papel
# Papel
# ¡Tenemos un empate!
# ¡Tus vidas siguen intactas, por los pelos!

# %%
#vidas
intentos_final = 0
vidas = 3
vida_1 = '🌕'
vida_2 = '🌗'
vida_3 = '🌚'
#creamos mensaje de bienvenida
jugadora = input('¿Cómo te llamas?')
bienvenida = print('¡Bienvenida', jugadora, 'al juego de Piedra, Papel o Tijera!')
bienvenida2 = print('Hoy, por ser tu primera vez, vamos a jugar al mejor de tres. Te enfrentarás a la computadora. ¿Estás preparada?')
#creamos bucle para que el juego no se ejecute solo una vez
while vidas > intentos_final:
    print('Actualmente tienes',vidas,'vidas. Cada vez que falles se te restará una. Si te quedas sin vidas pierdes la partida')
#creamos las preguntas para los dos jugadores
    opciones = ['Piedra', 'Papel', 'Tijera']
    jugador_1 = input('Elige una de las opciones: Piedra, Papel o Tijera').capitalize() #he usado capitalize para que si el usuario lo escribe en minúscula no de error el código 
#acotamos las respuestas que puede dar el jugador1
    if jugador_1 in opciones:
        print(jugador_1)
    else:
        if jugador_1 in opciones:
            print(jugador_1)
        elif jugador_1 != opciones:
            print('¡Tienes que elegir entre estas tres opciones! Piedra, Papel o Tijera')
        else:    
            pass 
#creamos las opciones para delimitar cada respuesta y lo que significa en la partida 
    if jugador_1 in opciones:
        jugador_2 = (random.choice(['Piedra', 'Papel', 'Tijera']))
        print(jugador_2)
        if jugador_1 == jugador_2:
            print("¡Tenemos un empate!")
            print("¡Tus vidas siguen intactas, por los pelos!")
        elif jugador_1 != jugador_2:
            if jugador_1 == 'Piedra' and jugador_2 == 'Papel':
                print('¡Gana',jugadora,'!')
            elif jugador_1 == 'Piedra' and jugador_2 == 'Tijera':
                print('¡Gana',jugadora,'!')
            elif jugador_1 == 'Tijera' and jugador_2 == 'Papel':
                print('¡Gana',jugadora,'!')
            elif jugador_2 == 'Piedra' and jugador_1 == 'Papel':
                vidas -= 1 
                print('¡Gana nuestra computadora! Ponte las pilas,',jugadora,'!')
                print('Oh no,',jugadora,'has perdido una vida!',vida_1,'. Te quedan un total de:',vidas)
            elif jugador_2 == 'Piedra' and jugador_1 == 'Tijera':
                vidas -= 1  
                print('¡Gana nuestra computadora! Cuidado con la revolución de las máquinas',jugadora,'!')
                print('Oh no,',jugadora,'has perdido una vida!',vida_2,'. Te quedan un total de:',vidas)
            elif jugador_2 == 'Tijera' and jugador_1 == 'Papel':
                vidas -= 1  
                print('¡Gana nuestra computadora! What´s happening',jugadora,'?!')
                print('Oh no,',jugadora,'has perdido una vida!',vida_2,'. Te quedan un total de:',vidas)
        else:
            pass 
if vidas == intentos_final:
    print('Se acabó el juego',jugadora,'¡Inténtalo otra vez cuando te veas con fuerzas!')

# %%
import random
#vidas
intentos_final = 0
vidas_jugadora1 = 3
vidas_jugador2 = 3
vida_1 = '🌕'
vida_2 = '🌗'
vida_3 = '🌚'
vida_4 = '⭐'
vida_5 = '🌟'
vida_6 = '💫'
#creamos mensaje de bienvenida
jugadora = input('¿Cómo te llamas?')
bienvenida = print('¡Bienvenida', jugadora, 'al juego de Piedra, Papel o Tijera!')
bienvenida2 = print('Hoy, por ser tu primera vez, tendrás tres vidas. Te enfrentarás a la computadora. ¿Estás preparada?')
#creamos bucle para que el juego no se ejecute solo una vez, dentro del bucle entran las preguntas para los jugadores, las respuestas acotadas y las opciones para delimitar la respuesta y el efecto 
#que tiene en la partida
print('Actualmente tienes',vidas_jugadora1,'vidas. Cada vez que falles se te restará una. Si te quedas sin vidas pierdes la partida')
while vidas_jugadora1 > intentos_final and vidas_jugador2 > intentos_final:
#creamos las preguntas para los dos jugadores
    opciones = ['Piedra', 'Papel', 'Tijera']
    jugador_1 = input('Elige una de las opciones: Piedra, Papel o Tijera').capitalize() #he usado capitalize para que si el usuario lo escribe en minúscula no de error el código 
#acotamos las respuestas que puede dar el jugador1
    if jugador_1 in opciones:
        print(jugador_1)
    else:
        if jugador_1 in opciones:
            print(jugador_1)
        elif jugador_1 != opciones:
            print('¡Tienes que elegir entre estas tres opciones! Piedra, Papel o Tijera')
        else:    
            pass 
#creamos las opciones para delimitar cada respuesta y lo que significa en la partida 
    if jugador_1 in opciones:
        jugador_2 = (random.choice(['Piedra', 'Papel', 'Tijera']))
        print(jugador_2)
        if jugador_1 == jugador_2:
            print("¡Tenemos un empate!")
            print("¡Tus vidas siguen intactas, por los pelos!")
        elif jugador_1 != jugador_2:
            if jugador_1 == 'Papel' and jugador_2 == 'Piedra':
                vidas_jugador2 -= 1
                print('¡Gana',jugadora,'!')
                print('¡Animo! A la computadora le quedan un total de',vida_4,vidas_jugador2)
            elif jugador_1 == 'Piedra' and jugador_2 == 'Tijera':
                vidas_jugador2 -= 1
                print('¡Gana',jugadora,'!')
                print('¡Venga! La computadora tiembla con un total de',vida_5,vidas_jugador2)
            elif jugador_1 == 'Tijera' and jugador_2 == 'Papel':
                vidas_jugador2 -= 1
                print('¡Gana',jugadora,'!')
                print('¡Dale! A la computadora le quedan',vida_6,vidas_jugador2)
            elif jugador_2 == 'Papel' and jugador_1 == 'Piedra':
                vidas_jugadora1 -= 1 
                print('¡Gana nuestra computadora! Ponte las pilas,',jugadora,'!')
                print('Oh no,',jugadora,'has perdido una vida!',vida_1,'. Te quedan un total de:',vidas_jugadora1)
            elif jugador_2 == 'Piedra' and jugador_1 == 'Tijera':
                vidas_jugadora1 -= 1  
                print('¡Gana nuestra computadora! Cuidado con la revolución de las máquinas',jugadora,'!')
                print('Oh no,',jugadora,'has perdido una vida!',vida_2,'. Te quedan un total de:',vidas_jugadora1)
            elif jugador_2 == 'Tijera' and jugador_1 == 'Papel':
                vidas_jugadora1 -= 1  
                print('¡Gana nuestra computadora! What´s happening',jugadora,'?!')
                print('Oh no,',jugadora,'has perdido una vida!',vida_2,'. Te quedan un total de:',vidas_jugadora1)
        else:
            pass  
#delimitamos un final para la partida cuando uno de los dos se quede sin vidas, ya sea la jugadora o la computadora
if vidas_jugadora1 == intentos_final:
    print('Se acabó el juego',jugadora,'¡Inténtalo otra vez cuando te veas con fuerzas!')
elif vidas_jugador2 == intentos_final:
    print('¡Has ganado',jugadora,'!')
else:
    pass
# Out:
# ¡Bienvenida Rocio  al juego de Piedra, Papel o Tijera!
# Hoy, por ser tu primera vez, tendrás tres vidas. Te enfrentarás a la computadora. ¿Estás preparada?
# Actualmente tienes 3 vidas. Cada vez que falles se te restará una. Si te quedas sin vidas pierdes la partida
# Piedra
# Papel
# ¡Gana nuestra computadora! Ponte las pilas, Rocio  !
# Oh no, Rocio  has perdido una vida! 🌕 . Te quedan un total de: 2
# ¡Tienes que elegir entre estas tres opciones! Piedra, Papel o Tijera
# ¡Tienes que elegir entre estas tres opciones! Piedra, Papel o Tijera
