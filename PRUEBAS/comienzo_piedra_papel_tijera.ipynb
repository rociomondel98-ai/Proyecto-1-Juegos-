# %% [markdown]
# Juego Piedra - Papel - Tijera.

# %%
# 0. importar randon

# 1. creamos una lista con las opciones

# 2. bienvenida

# 3. planteamos los dos jugadores

jugador_1 = "humano"

jugador_2 = "pc"
 
# 4. juegados_1 con input y jugador_2 random.choise(piedra, papel, tijeras)

# 5. crear el bucle

# %%
import random

# %%
import random
opciones= ["Piedra", "Papel", "tijera"]
jugador= input("Elige: Piedra, Papel o tijera ")
print(jugador)
computadora= random.choice(opciones)
print(computadora)
# Out:
# piedra
# tijera
