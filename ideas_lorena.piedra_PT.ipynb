# %%
# Recursos
import random
opciones= ["Piedra", "Papel", "tijera"]

#bienvenida
nombre_jugador= input("Indicame tu nombre de jugador")
print("Hola", nombre_jugador.upper(), "Bienvenida al juego")
print("(Piedra ✊🏻", "Papel ✋🏻", "tijera ✌🏻)")

#Definir players
jugador= input("Elige: Piedra, Papel o tijera ").lower().title()
print("👩🏻:",jugador)
computadora= random.choice(opciones)
print("🤖:",computadora)

#Logica de juego
if jugador == computadora :
    print("Empate 🤝🏻")


#FALTA DEFINIR:::::::
#TEXTO FUERA DE RANGO 
#QUE ELEMENTO ES MAYOR Y MENOR PARA GANAR
#CONTADOR DE VECES GANADAS POR JUGADOR 
#QUIERES JUGAR NUEVAMENTE? /REPETIR EL BUCLE
# Out:
# Hola LORENA Bienvenida al juego
# (Piedra ✊🏻 Papel ✋🏻 tijera ✌🏻)
# 👩🏻: Piedra
# 🤖: Piedra
# Empate 🤝🏻
