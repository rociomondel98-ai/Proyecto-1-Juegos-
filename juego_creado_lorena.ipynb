# %%
numero_secreto = 5
max_intentos = 3
intentos = 0
corazon = "❤️"
vidas = corazon * max_intentos
# Bienvenida
Nombre_usuario = input("Inserta tu nombre de jugador: ")
print("Te damos la bienvenida", Nombre_usuario.upper(), "🎮")
print("___________________ Comenzaremos el juego ___________________")
print("Tienes", vidas, "oportunidades")
# Bucle principal
while intentos < max_intentos:
    c_num_secreto = int(input("Dime un número del 1 al 10: ")) 
    # Número fuera de rango → pierde vida
    if c_num_secreto < 1 or c_num_secreto > 10:
        intentos += 1
        print("El número está fuera del rango 😬")
        print("Vidas:", corazon * (max_intentos - intentos))
        continue # sal del bucle y vuelve a empezar pero le restas una vida
    # gana en primer intento
    if c_num_secreto == numero_secreto and intentos == 0:
        print("¡Ganaste en el primer intento! 🥇")
        break # deten el bucle 
    # gana en intento 2 o 3
    elif c_num_secreto == numero_secreto:
        print(f"¡Ganaste en el intento {intentos + 1}! 🎉")
        break
    # intentos fallidos
    else:
        intentos += 1
        print("Incorrecto 😢")
        print("Vidas:", corazon * (max_intentos - intentos))
# Si se acaban los intentos
if intentos == max_intentos:
    print("Se acabaron los intentos. El número secreto era", numero_secreto)
