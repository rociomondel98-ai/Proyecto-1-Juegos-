# %%
notas = {
    "Ana": 8,
    "Luis": 5,
    "Marta": 9,
    "Pedro": 4
}

# Recorremos el diccionario
for key, value in notas.items():
    if value >= 6:
        print(key, "ha aprobado con", value)
    else:
        print(key, "ha suspendido con", value)
# Out:
# Ana ha aprobado con 8
# Luis ha suspendido con 5
# Marta ha aprobado con 9
# Pedro ha suspendido con 4
