# %%
#podríamos crear una función parecida para que no pueda introducir naa diferente a piedra,papel,tijera(ya bien decidamos en mayúsculas o minusculas)
#Por otro lado,si creamos la función, no debemos escribir el código en cada ronda del juego


contador_intentos=0

def input_tres_opciones(opcion1 ,opcion2, opcion3): #Defines una función para pedir un input con solo dos valores permitidos.Guardas las opciones válidas en una tupla, por ejemplo
    opciones="piedra","papel","tijera"
    while contador_intentos<3:
        
        if valor in opciones:
        
        else:
         intentos=intentos+1
    else:
        print("has terminado el número de intentos")
            
 #pero si quiero que tenga solo x ejemplo 3 intentos para escribir la respuesta (osea piedra pael o tijera?
    return valor #Devuelve la opción correcta.
    

respuesta = input_tres_opciones( "piedra", "papel", "tijera")
print(respuesta) #print de control
# Out:
#   Cell In[29], line 13
#     else:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 11

# %%
def input_tres_opciones(mensaje, opcion1, opcion2, opcion3, max_intentos=3):
    opciones = (opcion1, opcion2, opcion3)
    intentos = 0

    while intentos < max_intentos:
        valor = input(mensaje)

        if valor in opciones:
            return valor #escribió bien, se termina
        else:
            intentos =intentos +1
            print(f" Opción inválida.Te quedan {intentos}")

    print("Has terminado el número de intentos")
    return None

# %%
def input_tres_opciones(mensaje, opcion1, opcion2, opcion3, max_intentos=3):
    opciones = (opcion1, opcion2, opcion3)
    intentos = 0

    while intentos < max_intentos:
        valor = input(mensaje)

        if valor in opciones:
            return valor #escribió bien, se termina
        else:
            intentos =intentos +1
            print(f" Opción inválida. Intento {intentos}/{max_intentos}")

    return("Has terminado el número de intentos")

# %%
def input(mensaje, opcion1, opcion2, opcion3, max_intentos=3):
    opciones = (opcion1, opcion2, opcion3)
    intentos = 0

    while intentos < max_intentos:
        valor = input(mensaje)

        if valor in opciones:
            return valor
        else:
            intentos += 1
            print("Opción inválida")

    return "Has terminado el número de intentos"

respuesta=input("Elije","piedra","papel","tijera")

print(respuesta)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 16
#      12             print("Opción inválida")
#      14     return "Has terminado el número de intentos"
# ---> 16 respuesta=input("Elije", "piedra", "papel", "tijera")
#
# Cell In[42], line 6, in input(mensaje, opcion1, opcion2, opcion3, max_intentos)
#       3 intentos = 0
#       5 while intentos < max_intentos:
# ----> 6     valor = input(mensaje)
#       8     if valor in opciones:
#       9         return valor
#
# TypeError: input() missing 3 required positional arguments: 'opcion1', 'opcion2', and 'opcion3'
